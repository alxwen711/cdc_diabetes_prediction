# %% [markdown]
# # Vancouver Tree Genus Prediction

# %% [markdown]
# ## Summary

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Methods and Results

# %% [markdown]
# ### Load Data

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# ### Data Summary

# %% [markdown]
# ### Visualizations

# %% [markdown]
# ### Tree Classification

# %% [markdown]
# ### Result Visualizations

# %% [markdown]
# ## Discussion

# %% [markdown]
# ## References
